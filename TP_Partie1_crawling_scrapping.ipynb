# %% [markdown]
# # **Cours de Manipulation des données avec Python .**

# %% [markdown]
# # Réalisé par Ketsia MULAPI TITA

# %% [markdown]
# ## **TP pour la récupération des données sur internet : PREMIERE PARTIE**

# %%
VOTRE_NOM_ICI ="Camara Djibril"
print(VOTRE_NOM_ICI)
# Out:
# Camara Djibril

# %% [markdown]
# # **TRAVAIL PRATIQUE**

# %% [markdown]
# Dans un notebook propre à vous, répondez à chacune des parties suivantes :

# %% [markdown]
# Partie 1 : HTML

# %%
# Vous allez construire un fichier HTML de votre choix, objectif ? construire une page web static (pas de javascript, juste HTML)
pages = """
    <!DOCTYPE html>
    <html>
    <head>
        <title>Ma page web</title>
    </head>
    <body>
        <h1>Ma page web</h1>
        <p>Je suis un paragraphe</p>
    </body>
    </html>
"""

# %% [markdown]
# Partie 2 : XML - Xpath (manuellement)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# vous allez analyser et comprendre le fichier XML suivant  : spatial.xml

# écrire la syntaxe xpath qui répond aux questions ci-dessous , lors de la deuxième partie de ce chapitre vous aurez l'occasion d'utiliser python avec xpath.

# %% [markdown]
# Récupérez le fichier spatial.xml. Trouvez les requêtes XPath récupérant les
# informations demandées ci-dessous (Plusieurs solutions sont possibles, vous met-
# trez celles qui vous paraissent pertinentes dans votre rapport. Attention, il vous est parfois demandé le texte et parfois les noeuds) :
#
# — le nom des nations qui ont un programme spatial
#
# — les astronautes dont le rôle a été au moins une fois commandant
#
# — les dates des missions habités
#
# — la mission du 1965-01-09 si elle est habitée (si elle ne l’est pas, la requête
# ne renverra rien)
#
# — le nom du commandant de la mission Apollo 11
#
# — le nom des mission sans astronaute enregistré
#
# — la dernière mission américaine enregistrée dans le fichier
#
# — la mission qui précède Voskhod 2 dans le fichier
#
# — les missions où 1 seul astronaute est enregistré

# %%
from lxml import etree
tree = etree.parse("spatial.xml")
for nation in tree.xpath("//programmes/nation/@nom"):
    print(nation)
# Out:
# USA
# URSS

# %%
# les astronautes dont le rôle a été au moins une fois commandant
for astronauts in tree.xpath("//astronaute[@role='commandant']/text()"):
    print(astronauts)
# Out:
# Virgil Grissom
# John Glenn
# Scott Carpenter
# Gordon Cooper
# Virgil Grissom
# James McDivitt
# Gordon Cooper
# Franck Borman
# Neil Armstrong
# Thomas Stafford
# John Young
# Pete Conrad
# Jim Lovell
# Virgil Grissom
# Walter Schirra
# Franck Borman
# James McDivitt
# Thomas Stafford
# Neil Armstrong
# Pete Conrad
# Jim Lovell
# Alan Shepard
# Dave Scott
# John Young
# Gene Cernan
# Youri Gagarine
# Guerman Titov
# Andrian Nikolaïev
# Pavel Popovitch
# Valeri Bykovski
# Valentina Terechkova
# Vladimir Komarov
# Pavel Beliaïev
# Vladimir Komarov
# Gueorgui Beregovoi
# Vladimir Shatalov
# Boris Volynov
# Georgi Shonin

# %%
missions = tree.xpath("//mission[@type='habité']/@date")
for mission in missions:
    print(mission)
# Out:
# 1961-05-05
# 1961-06-21
# 1962-02-20
# 1962-05-24
# 1962-10-03
# 1963-05-15
# 1965-03-23
# 1965-06-03
# 1965-08-21
# 1965-12-15
# 1965-12-04
# 1966-03-16
# 1966-06-03
# 1966-07-18
# 1966-09-12
# 1966-11-11
# 1967-01-27
# 1968-10-11
# 1968-12-21
# 1969-03-03
# 1969-05-18
# 1969-07-16
# 1969-11-14
# 1970-04-11
# 1971-01-31
# 1971-07-26
# 1972-04-16
# 1972-12-07
# 1961-04-12
# 1961-08-06
# 1962-08-11
# 1962-08-12
# 1963-06-14
# 1963-06-16
# 1964-10-12
# 1965-03-18
# 1967-04-23
# 1968-10-26
# 1969-01-14
# 1969-01-15
# 1969-10-11

# %%
# la mission du 1965-01-09 si elle est habitée (si elle ne l’est pas, la requête ne renverra rien)
mission = soup.find('mission', date='1965-01-09', type='habitÃ©')
if mission:
    print(mission['nom'])

# %%
# le nom du commandant de la mission Apollo 11
mission = soup.find('mission', nom='Apollo 11')
commander = mission.find('astronaute', role='commandant')
print(commander.text)
# Out:
# Neil Armstrong

# %%
# le nom des mission sans astronaute enregistré
missions = soup.find_all('mission')
for mission in missions:
    if not mission.find('astronaute'):
        print(mission['nom'])
# Out:
# Gemini 1
# Gemini 2
# Apollo 4
# Apollo 5
# Apollo 6
# Soyouz 2

# %%
# la dernière mission américaine enregistrée dans le fichier
nation = soup.find('nation', nom='USA')
missions = nation.find_all('mission')
last_mission = missions[-1]
print(last_mission['nom'])
# Out:
# Apollo 17

# %%
# la mission qui précède Voskhod 2 dans le fichier
mission_voskhod2 = soup.find('mission', nom='Voskhod 2')
preceding_mission = mission_voskhod2.find_previous_sibling('mission')
if preceding_mission:
    print(preceding_mission['nom'])
# Out:
# Voskhod 1

# %%
# les missions où 1 seul astronaute est enregistré
missions = soup.find_all('mission')
for mission in missions:
    astronauts = mission.find_all('astronaute')
    if len(astronauts) == 1:
        print(mission['nom'])
# Out:
# Mercury 3
# Mercury 4
# Mercury 6
# Mercury 7
# Mercury 8
# Mercury 9
# Vostok 1
# Vostok 2
# Vostok 3
# Vostok 4
# Vostok 5
# Vostok 6
# Soyouz 1
# Soyouz 3

# %% [markdown]
# -------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# vous allez construire un fichier XML de votre choix, en vous basant sur une logique structurelle de données simple isnpirée de NETFLIX :
# Titre Film, Producteur, Acteurs, Années, Genres, Pays, Langues, etc.
# Vous pouvez vous limiter à 3 enregistrements !
netflix = """ 
<netflix>
    <Film>
        <Titre>The Shawshank Redemption</Titre>
        <Producteur>Frank Darabont</Producteur>
        <Acteurs>
            <Acteur>Tim Robbins</Acteur>
            <Acteur>Morgan Freeman</Acteur>
        </Acteurs>
        <Annees>1994</Annees>
        <Genres>
            <Genre>Drama</Genre>
            <Genre>Crime</Genre>
        </Genres>
        <Pays>USA</Pays>
        <Langues>
            <Langue>English</Langue>
        </Langues>
    </Film>
    <Film>
        <Titre>The Godfather</Titre>
        <Producteur>Francis Ford Coppola</Producteur>
        <Acteurs>
            <Acteur>Marlon Brando</Acteur>
            <Acteur>Al Pacino</Acteur>
        </Acteurs>
        <Annees>1972</Annees>
        <Genres>
            <Genre>Crime</Genre>
            <Genre>Drama</Genre>
        </Genres>
        <Pays>USA</Pays>
        <Langues>
            <Langue>English</Langue>
            <Langue>Italian</Langue>
        </Langues>
    </Film>
    <Film>
        <Titre>Pulp Fiction</Titre>
        <Producteur>Quentin Tarantino</Producteur>
        <Acteurs>
            <Acteur>John Travolta</Acteur>
            <Acteur>Samuel L. Jackson</Acteur>
        </Acteurs>
        <Annees>1994</Annees>
        <Genres>
            <Genre>Crime</Genre>
            <Genre>Drama</Genre>
        </Genres>
        <Pays>USA</Pays>
        <Langues>
            <Langue>English</Langue>
        </Langues>
    </Film>
</netflix> 
"""

# %% [markdown]
# Partie 3 : Faire des RegEx avec python pour aider Amazone dans la validaition des informations entrées pour la création des comptes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Faire une fonction python qui permet de vérifier si les informations d'un individu sont correcre , au moment de la création du compte Amazone:


# - Nom : doit être ne majuscule
# - Prénom : commence apr une majuscule
# - Data de naissance : en jours mois année de deux façons différentes : JJ/MM/AAAA ou JJ Mois AAAA
# - Adresse : Numéro, voie (rue, avenue, ...), ville, code postale

# %% [markdown]
# Partie 4 : Robots.txt , Connaître les technos d'un site web et les examinations (plan, taille)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Choisissez un site web qui soit celui d'un ministère français,

# Analysez son Robots.txt : écrivez ce que vous comprenez

# Trouvez les technologies utilisées avec builtwith

# Trouvez le owner et/ou l'host avec whois

# %% [markdown]
# Partie 5 : Résolvez les 6 questions restantes sur l'équipe de france

# %% [markdown]
# ![image.png](data:image/png;base64,...) X ![image.png](data:image/png;base64,...)

# %%
# 5) Combien de fois l'équipe de France a-t-elle remporté la Coupe du Monde de la FIFA ?

# %%
# 6) En quelle année l'équipe de France a-t-elle remporté son premier Championnat d'Europe UEFA ?

# %%
# 7) Lister les cinq derniers adversaires de l'équipe de France selon la section "Derniers matchs et prochains matchs"

# %%
# 8) Quel est le surnom donné à l'équipe de France de football ?

# %%
# 9) Combien de joueurs l'équipe de France compte-t-elle dans son "Hall of Fame" ?

# %%
# 10) Quelle est la plus large victoire obtenue par l'équipe de France ?

# %% [markdown]
# Partie 6 : WEB CRAWLING

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Complétez la fonction de web crawling en faisant une recherche d'hyperliens jusqu'à la 4ème génération (la fonction devra donc être récursive et s'arrêter en fonction d'un critère)
# mémorisez les résultats dans un dictionnaire python sous cette forme :
# web_indexation = { "Famille" : { "parent_1 " : {"parent_1_1" : {
#                                                                    "enfant_1_1_1" : [liste_des_petits_enfants],
#                                                                    "enfant_1_1_2" : petit_enfant
#                                                                },
#                                                },
#                                       "parent_2" : ... ,
#                                        ...
#                                       "parent_n" : ... ,
#                                      }}

# %% [markdown]
# ------------------------------------------------------------------
# # A la fin de cette expérience, rendez votre fichier notebook et sa version pdf !!!
